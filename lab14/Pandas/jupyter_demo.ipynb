# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Numpy Array

# %%
arr1 = np.array([1,2,3])
arr2 = np.array([4,5,6])

arr1+arr2
# Out:
# array([5, 7, 9])

# %%
l1 = [1,2,3]
l2 = [4,5,6]
l1+l2
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# ## Series object

# %%
ds = pd.Series(arr1, index=['a', 'b', 'c'])
ds
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
ds.loc['b']
ds.iloc[1]
# Out:
# 2

# %% [markdown]
# ## DataFrame

# %%
# create Series Object:
prices_ds = pd.Series([1.5, 2, 2.5, 3],
                        index=["apples", "oranges", "bananas", "strawberries"])

prices_ds
# Out:
# apples          1.5
# oranges         2.0
# bananas         2.5
# strawberries    3.0
# dtype: float64

# %%
# create DataFrame Object from prices Series:
prices_df = pd.DataFrame(prices_ds, columns=['price'])
prices_df
# Out:
#               price
# apples          1.5
# oranges         2.0
# bananas         2.5
# strawberries    3.0

# %%
# load data in DF from csv:
df = pd.read_csv('https://raw.githubusercontent.com/geekcourses/JupyterNotebooksExamples/master/datasets/various/drinks.csv')
df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %%
# save df to excel
df.to_excel('drinks.xlsx')

# %%
df.sort_values(by='beer_servings', inplace=True)
df
# Out:
#             country  beer_servings  spirit_servings  wine_servings  \
# 0       Afghanistan              0                0              0
# 40     Cook Islands              0              254             74
# 79             Iran              0                0              0
# 90           Kuwait              0                0              0
# 97            Libya              0                0              0
# ..              ...            ...              ...            ...
# 135          Poland            343              215             56
# 65          Germany            346              117            175
# 62            Gabon            347               98             59
# 45   Czech Republic            361              170            134
# 117         Namibia            376                3              1
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 40                            5.9        OC
# ...

# %%
df.iloc[-5:, 1:4]
# Out:
#      beer_servings  spirit_servings  wine_servings
# 135            343              215             56
# 65             346              117            175
# 62             347               98             59
# 45             361              170            134
# 117            376                3              1

# %%
df.set_index('country', inplace=True)

# %%
#  df.loc[row_indexer,column_indexer]
df.loc['Afghanistan', 'wine_servings']
# Out:
# 0

# %%
df.iloc[0, 2]
# Out:
# 0

# %%
df
# Out:
#                 beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan                 0                0              0
# Cook Islands                0              254             74
# Iran                        0                0              0
# Kuwait                      0                0              0
# Libya                       0                0              0
# ...                       ...              ...            ...
# Poland                    343              215             56
# Germany                   346              117            175
# Gabon                     347               98             59
# Czech Republic            361              170            134
# Namibia                   376                3              1
#
#                 total_litres_of_pure_alcohol continent
# country
# Afghanistan                              0.0        AS
# Cook Islands                             5.9        OC
# ...

# %%
df.loc['Germany':'Namibia', 'beer_servings': 'total_litres_of_pure_alcohol']
# Out:
#                 beer_servings  spirit_servings  wine_servings  \
# country
# Germany                   346              117            175
# Gabon                     347               98             59
# Czech Republic            361              170            134
# Namibia                   376                3              1
#
#                 total_litres_of_pure_alcohol
# country
# Germany                                 11.3
# Gabon                                    8.9
# Czech Republic                          11.8
# Namibia                                  6.8

# %%
df.iloc[188:, 0:3]
# Out:
#                 beer_servings  spirit_servings  wine_servings
# country
# Poland                    343              215             56
# Germany                   346              117            175
# Gabon                     347               98             59
# Czech Republic            361              170            134
# Namibia                   376                3              1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 193 entries, Afghanistan to Namibia
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   beer_servings                 193 non-null    int64
#  1   spirit_servings               193 non-null    int64
#  2   wine_servings                 193 non-null    int64
#  3   total_litres_of_pure_alcohol  193 non-null    float64
#  4   continent                     170 non-null    object
# dtypes: float64(1), int64(3), object(1)
# memory usage: 13.1+ KB

# %%
df.iloc[:6, :-1].max(axis=1)
# Out:
# country
# Afghanistan       0.0
# Cook Islands    254.0
# Iran              0.0
# Kuwait            0.0
# Libya             0.0
# Maldives          0.0
# dtype: float64

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#             country  beer_servings  spirit_servings  wine_servings  \
# 0       Afghanistan              0                0              0
# 1      Cook Islands              0              254             74
# 2              Iran              0                0              0
# 3            Kuwait              0                0              0
# 4             Libya              0                0              0
# ..              ...            ...              ...            ...
# 188          Poland            343              215             56
# 189         Germany            346              117            175
# 190           Gabon            347               98             59
# 191  Czech Republic            361              170            134
# 192         Namibia            376                3              1
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             5.9        OC
# ...

# %%
# TASK: find country with max wine servings
max_wine = df['wine_servings'].max()
max_wine
# Out:
# 370

# %%
filter = df['wine_servings']==max_wine
filter
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 188    False
# 189    False
# 190    False
# 191    False
# 192    False
# Name: wine_servings, Length: 193, dtype: bool

# %%
df[filter]
# Out:
#     country  beer_servings  spirit_servings  wine_servings  \
# 123  France            127              151            370
#
#      total_litres_of_pure_alcohol continent
# 123                          11.8        EU

# %%
df[ df['beer_servings']==df['beer_servings'].max() ]
# Out:
#      country  beer_servings  spirit_servings  wine_servings  \
# 192  Namibia            376                3              1
#
#      total_litres_of_pure_alcohol continent
# 192                           6.8        AF

# %%
# TASK: Find all coutries, which did not consume beer:
filter = df['beer_servings']==0
df[filter].country
# Out:
# 0          Afghanistan
# 1         Cook Islands
# 2                 Iran
# 3               Kuwait
# 4                Libya
# 5             Maldives
# 6     Marshall Islands
# 7               Monaco
# 8             Pakistan
# 9           San Marino
# 10          Bangladesh
# 11        Saudi Arabia
# 12          Mauritania
# 13             Somalia
# 14         North Korea
# Name: country, dtype: object

# %%
# TASK: find EU country with max beer_servings
df
# Out:
#             country  beer_servings  spirit_servings  wine_servings  \
# 0       Afghanistan              0                0              0
# 1      Cook Islands              0              254             74
# 2              Iran              0                0              0
# 3            Kuwait              0                0              0
# 4             Libya              0                0              0
# ..              ...            ...              ...            ...
# 188          Poland            343              215             56
# 189         Germany            346              117            175
# 190           Gabon            347               98             59
# 191  Czech Republic            361              170            134
# 192         Namibia            376                3              1
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             5.9        OC
# ...

# %%
eu_df = df[ df['continent']=='EU' ]
eu_df[ eu_df['beer_servings']==eu_df['beer_servings'].max() ]
# Out:
#             country  beer_servings  spirit_servings  wine_servings  \
# 191  Czech Republic            361              170            134
#
#      total_litres_of_pure_alcohol continent
# 191                          11.8        EU

# %%
df['continent'].unique()
# Out:
# array(['AS', 'OC', 'AF', 'EU', nan, 'SA'], dtype=object)

# %%
max_beer_per_group = df.groupby(by='continent')['beer_servings'].max()
max_beer_per_group
# Out:
# continent
# AF    376
# AS    247
# EU    361
# OC    306
# SA    333
# Name: beer_servings, dtype: int64

# %% [markdown]
# ## DataFrames Manipulations

# %%
eu_weather_df = pd.DataFrame({
  "town": ["Atina", "Oslo", "London"],
  "temp":[35,21,25],
  "rain": [False, False, True ]
})
eu_weather_df
# Out:
#      town  temp   rain
# 0   Atina    35  False
# 1    Oslo    21  False
# 2  London    25   True

# %%
eu_weather_df.drop(columns='rain')
# Out:
#      town  temp
# 0   Atina    35
# 1    Oslo    21
# 2  London    25

# %%
bg_weather_df = pd.DataFrame({
  "town": ["Sofia", "Sandanski", "Pleven"],
  "temp":[25,32,21],
  "rain": [False, False, True ]
})
bg_weather_df
# Out:
#         town  temp   rain
# 0      Sofia    25  False
# 1  Sandanski    32  False
# 2     Pleven    21   True

# %%
eu_weather_df
# Out:
#      town  temp   rain
# 0   Atina    35  False
# 1    Oslo    21  False
# 2  London    25   True

# %%
eu_weather_df.insert(2, "wind", [1.5, 7.5, 4])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_15693/2333724999.py in ?()
# ----> 1 eu_weather_df.insert(2, "wind", [1.5, 7.5, 4])
#       2 eu_weather_df
#
# /media/nemsys/data/projects/courses/ProgressBG/ProgressBG-Python/ProgressBG-Python-Labs/.venv/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, loc, column, value, allow_duplicates)
#    5154                 "'self.flags.allows_duplicate_labels' is False."
#    5155             )
#    5156         if not allow_duplicates and column in self.columns:
#    5157             # Should this be a different kind of error??
# -> 5158             raise ValueError(f"cannot insert {column}, already exists")
#    5159         if not is_integer(loc):
#    5160             raise TypeError("loc must be int")
#    5161         # convert non stdlib ints to satisfy typing checks
#
# ...

# %%
eu_weather_df
# Out:
#      town  temp  wind   rain
# 0   Atina    35   1.5  False
# 1    Oslo    21   7.5  False
# 2  London    25   4.0   True

# %%
bg_weather_df
# Out:
#         town  temp   rain
# 0      Sofia    25  False
# 1  Sandanski    32  False
# 2     Pleven    21   True

# %%
pd.concat( [eu_weather_df, bg_weather_df] )
# Out:
#         town  temp  wind   rain
# 0      Atina    35   1.5  False
# 1       Oslo    21   7.5  False
# 2     London    25   4.0   True
# 0      Sofia    25   NaN  False
# 1  Sandanski    32   NaN  False
# 2     Pleven    21   NaN   True

# %%
pd.concat( [eu_weather_df, bg_weather_df], axis=1)
# Out:
#      town  temp  wind   rain       town  temp   rain
# 0   Atina    35   1.5  False      Sofia    25  False
# 1    Oslo    21   7.5  False  Sandanski    32  False
# 2  London    25   4.0   True     Pleven    21   True
